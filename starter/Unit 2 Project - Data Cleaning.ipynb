# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
####### TO DO ########

# load house_data.csv into a dataframe using pd.read_csv()

# load house_sales.csv into a dataframe using pd.read_csv()

######################

# %%
import pandas as pd

# %%
house_sales = pd.read_csv("house_sales.csv")

# %%
house_data = pd.read_csv("house_data.csv")

# %%
house_sales.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
house_data.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
house_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %%
house_df.tail()
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 21607  2997800021         3       2.50         1310    1294.0     2.0
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 21607         No  Very Poor    OK Condition    8.0      1180.0            130
# 21608         No  Very Poor    OK Condition    8.0      1530.0              0
# 21609         No  Very Poor    OK Condition    8.0      2310.0              0
# 21611         No  Very Poor    OK Condition    8.0      1600.0              0
# 21612         No  Very Poor    OK Condition    7.0      1020.0              0
#
#        year_built  zipcode      lat     long  sqft_living_15  sqft_lot_15
# ...

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was loaded succussfully

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**:
# > Description:The id of the house
# >
# > Data type: string
#
# **bedrooms**:
# > Description:Number of bedroom in the house
# >
# > Data type:integer
#
# **bathrooms**:
# > Description:Number of bathrooms in the house
# >
# > Data type:float
#
# **sqft_living**:
# > Description:The number of sq ft available inside the house for living
# >
# > Data type:integer
#
# **sqft_lot**:
# > Description:The total sq footage of the lot the house is built on
# >
# > Data type:float
#
# **floors**:
# > Description:The number of floors in the house
# >
# > Data type:float
#
# **waterfront**:
# > Description:Is the property a waterfront property
# >
# > Data type:string
#
# **view**:
# > Description:What is the view?
# >
# > Data type:string
#
# **condition**:
# > Description:The condition of the house
# >
# > Data type:string
#
# **grade**:
# > Description:What grade/quality is it
# >
# > Data type:float
#
# **sqft_above**:
# > Description:Whats the above ground sq ft of the house
# >
# > Data type:float64
#
# **sqft_basement**:
# > Description:What is the below ground sq ft of the house
# >
# > Data type:integer
#
# **yr_built**:
# > Description:When was the house built
# >
# > Data type:string
#
# **yr_renovated**:
# > Description:If renovated, which year did the renovation take place
# >
# > Data type:string
#
# **zipcode**:
# > Description:Which zipcode is it located in
# >
# > Data type:string
#
# **lat**:
# > Description:Which latitude is it located in
# >
# > Data type:float
#
# **long**:
# > Description:Which longitude is it located in
# >
# > Data type:float
#
# **sqft_living15**:
# > Description:Not sure what this means
# >
# > Data type:integer
#
# **sqft_lot15**:
# > Description:Not sure what this means
# >
# > Data type:integer

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description:The ID of the house
# >
# > Data type:integer64
#
# **date**:
# > Description:The last sale date
# >
# > Data type:Object
#
# **price**:
# > Description:The last sale price
# >
# > Data type:Object

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data

# create a copy of sales_data

# %%
house_df = house_data.copy()

# %%
sales_df = house_sales.copy()

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully

sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
house_df.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully

# %%
sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
import pandas as pd

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
house_df.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %% [markdown]
# Answer: Delete Unamed:0 column,
# Remove question mark from Waterfront from house_df
# Delete Unnamed:0 column,  and
# change DATE to title case in sales_df,
# Change SQFT living, SQFT lot, House Condition, SWFT above, SQFT basement, Year Built, Year Renovated, SQFT living 15 and SQFT lot 15 to snake case.
# Change all columns to lower case

# %%
sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# Change all columns to lower case and delete unnamed:0 column

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
house_df.View.nunique()
# Out:
# 5

# %% [markdown]
# Answer:
#  Change "ID" column dtype to string. Also change "year built" and "year renovated"  dtype to string as well as zipcode

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# Answer: Delete unnamed column, Change "ID" dtype to string, Change dtype of "date" to datetime, remove $ sign in front of price and , in the price and change "price" dtype to float

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?

# %% [markdown]
# Yes. Answered above

# %% [markdown]
# A: #### TO DO #####

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.isna()
# Out:
#        Unnamed: 0     ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           False  False     False      False        False     False   False
# 1           False  False     False      False        False     False   False
# 2           False  False     False      False        False     False   False
# 3           False  False     False      False        False     False   False
# 4           False  False     False      False        False     False   False
# ...           ...    ...       ...        ...          ...       ...     ...
# 21608       False  False     False      False        False     False   False
# 21609       False  False     False      False        False     False   False
# 21610       False  False     False      False        False     False   False
# 21611       False  False     False      False        False     False   False
# 21612       False  False     False      False        False     False   False
#
# ...

# %%
house_df.isna().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %%
sales_df.isna().sum()
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %%
house_df.waterfront.unique()
# Out:
# ['No', 'Yes']
# Categories (3, object): [2050, 'No', 'Yes']

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# In the House_df dataframe: Bahtrooms, SQFT lot, Waterfront?, View, House Condition, Grade, SQFT above, Year built, Year renovated, Zipcode, Lat, and Long have missing values
# No missing values in the sales_df dataframe

# %% [markdown]
# A: ##### TO DO #####

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Q: Which variables/columns have outliers?

# %%
house_df.describe()
# Out:
#         Unnamed: 0            ID      Bedrooms     Bathrooms   SQFT living  \
# count  21613.00000  2.161300e+04  21613.000000  21611.000000  21613.000000
# mean   10806.00000  4.580302e+09      3.372091      2.115173   2079.899736
# std     6239.28002  2.876566e+09      0.947533      0.772019    918.440897
# min        0.00000  1.000102e+06      0.000000      0.000000    290.000000
# 25%     5403.00000  2.123049e+09      3.000000      1.750000   1427.000000
# 50%    10806.00000  3.904930e+09      3.000000      2.250000   1910.000000
# 75%    16209.00000  7.308900e+09      4.000000      2.500000   2550.000000
# max    21612.00000  9.900000e+09     33.000000     10.000000  13540.000000
#
#            SQFT lot        Floors         Grade    SQFT above  SQFT basement  \
# count  2.161100e+04  21613.000000  21611.000000  21612.000000   21613.000000
# mean   1.510388e+04      1.494309      7.656795   1788.861281     291.509045
# ...

# %% [markdown]
# In the house_df dataframe: Bedroooms, Bathrooms, SQFT living, SQFT LOT, SQFT above, SQFT basement, Year built and SQFT living 15, AND SQFT LOT 15 have outliers

# %%
sales_df.describe()
# Out:
#         Unnamed: 0            Id
# count  21613.00000  2.161300e+04
# mean   10806.00000  4.580302e+09
# std     6239.28002  2.876566e+09
# min        0.00000  1.000102e+06
# 25%     5403.00000  2.123049e+09
# 50%    10806.00000  3.904930e+09
# 75%    16209.00000  7.308900e+09
# max    21612.00000  9.900000e+09

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_df.head(10)
# Out:
#    Unnamed: 0          Id             DATE          Price
# 0           0  7129300520  20141013T000000    $221,900.00
# 1           1  6414100192  20141209T000000    $538,000.00
# 2           2  5631500400  20150225T000000    $180,000.00
# 3           3  2487200875  20141209T000000    $604,000.00
# 4           4  1954400510  20150218T000000    $510,000.00
# 5           5  7237550310  20140512T000000  $1,225,000.00
# 6           6  1321400060  20140627T000000    $257,500.00
# 7           7  2008000270  20150115T000000    $291,850.00
# 8           8  2414600126  20150415T000000    $229,500.00
# 9           9  3793500160  20150312T000000    $323,000.00

# %% [markdown]
# No outliers in the sales dataframe

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("Bedrooms")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("Bathrooms")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("SQFT living")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("SQFT lot")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("Floors")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("Grade")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("SQFT above")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("SQFT basement")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("Year Built")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("Year Renovated")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("SQFT living 15")
plt.show()

# %%
plt.figure(figsize = (12, 8))
house_df.boxplot("SQFT lot 15")
plt.show()

# %%
house_df.describe()
# Out:
#         Unnamed: 0            ID      Bedrooms     Bathrooms   SQFT living  \
# count  21613.00000  2.161300e+04  21613.000000  21611.000000  21613.000000
# mean   10806.00000  4.580302e+09      3.372091      2.115173   2079.899736
# std     6239.28002  2.876566e+09      0.947533      0.772019    918.440897
# min        0.00000  1.000102e+06      0.000000      0.000000    290.000000
# 25%     5403.00000  2.123049e+09      3.000000      1.750000   1427.000000
# 50%    10806.00000  3.904930e+09      3.000000      2.250000   1910.000000
# 75%    16209.00000  7.308900e+09      4.000000      2.500000   2550.000000
# max    21612.00000  9.900000e+09     33.000000     10.000000  13540.000000
#
#            SQFT lot        Floors         Grade    SQFT above  SQFT basement  \
# count  2.161100e+04  21613.000000  21611.000000  21612.000000   21613.000000
# mean   1.510388e+04      1.494309      7.656795   1788.861281     291.509045
# ...

# %% [markdown]
# A: ##### TO DO #####

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Unit 2 data cleaning plan:
#
# House_dh  Issues with columns:
# Delete ::0 from Unamed column,
# Remove question mark from Waterfront from house_df
# Change all columns to lower case
# Change SQFT living, SQFT lot, House Condition, SWFT above, SQFT basement, Year Built, Year Renovated, SQFT living 15 and SQFT lot 15 to snake case.
#
# House_df datatype issues:
# Change Id to dtype string
# Change year built dtype to string
# Change yr renovated and zip code also to string
#
# House_df missing values:
# Bahtrooms, SWFT lot, Waterfront?, View, House Condition, Grade, SQFT above, Year built, Year renovated, Zipcode, Lat, and Long
# Outliers:
# Bedroooms, Bathrooms, SQFT living, SQFT Lot,  SQFT above, SQFT basement, Year built and SQFT living 15, SQFT lot 15 have outliers
# Sales_df issues:
# Delete :0 from Unnamed column,
# Change all columns to lower case
# Change dtype of date column to datetime
# Remove $ sign in front of price, the , in the price and change dtype to float

# %%
For this project, you will execute your data cleaning plan using a DEFINE, CLEAN, TEST approach. This is a good way to ensure you clean everything you planned to in the data and keep track of each task.

In your provided code, there is a framework to complete this task. For each item you wrote in your cleaning plan, you will complete a DEFINE / CLEAN / TEST block of code. Here are two examples:

Example #1

_images/image8.png
Example #2

_images/image1.png
See examples above for how your code needs to be structured. Several cleaning tasks need to be completed. Use the queue, ask your tech lead for help, or see the solution file for assistance.

# %% [markdown]
# #### Data Cleaning Plan:
#
# ####### TO DO #######

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
### DEFINE ### House_df

#Delete Unamed:0 column
### CLEAN ### 

house_df.drop(columns=["Unnamed: 0"], inplace =True)
### TEST ###

house_df.head()
# Out:
#            ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors Waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         View  House Condition  Grade  SQFT above  SQFT basement  Year Built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###

#Change all column headers to lower case 
### CLEAN ### 

house_df.columns = house_df.columns.str.lower()
### TEST ###
house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft living  sqft lot  floors waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         view  house condition  grade  sqft above  sqft basement  year built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###

#Change all columns to snake case 
### CLEAN ### 

house_df.rename(columns = {"sqft living": "sqft_living", "sqft lot": "sqft_lot", "house condition": "house_condition", "sqft above": "sqft_above", "sqft basement": "sqft_basement", "year built": "year_built", "year renovated": "year_renovated", "sqft living 15": "sqft_living_15", "sqft lot 15": "sqft_lot_15" }, inplace = True)

### TEST ###
house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###

#Remove ? from waterfront column
### CLEAN ### 

#house_df.waterfront = house_df.waterfront?.str.replace ("?", "")
#house_df['waterfront'] = house_df['waterfront?'].apply(lambda x: re.sub(pattern, '', x))
#house_df["waterfront"] = house_df["waterfront?"].str.replace("?", "")
house_df.rename(columns={"waterfront?": "waterfront"}, inplace=True)
### TEST ###
house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  int64
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21610 non-null  float64
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###
#Change "Zipcode"dtype to string
### CLEAN ### 

house_df.zipcode = house_df.zipcode.astype(str)
### TEST ###
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  int64
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21613 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###

#Change dtype of id to string
### CLEAN ### 

house_df.id = house_df.id.astype(str)
### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21613 non-null  object
#  15  lat              21612 non-null  float64
# ...

# %%
#Sales_df dataframe:
### DEFINE ###

#Delete unanmed:0 column
### CLEAN ### 

c
### TEST ###
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      21613 non-null  int64
#  1   DATE    21613 non-null  object
#  2   Price   21609 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 506.7+ KB

# %%
### DEFINE ###

#Change dtype of date to datetime
### CLEAN ### 

sales_df["date"] = pd.to_datetime(sales_df["date"])
### TEST ###

sales_df.head()
# Out:
#            id       date        price
# 0  7129300520 2014-10-13  $221,900.00
# 1  6414100192 2014-12-09  $538,000.00
# 2  5631500400 2015-02-25  $180,000.00
# 3  2487200875 2014-12-09  $604,000.00
# 4  1954400510 2015-02-18  $510,000.00

# %%
### DEFINE ###

#Change all column headers to lower case 
### CLEAN ### 

sales_df.columns = sales_df.columns.str.lower()
### TEST ###
sales_df.head()
# Out:
#            id       date        price
# 0  7129300520 2014-10-13  $221,900.00
# 1  6414100192 2014-12-09  $538,000.00
# 2  5631500400 2015-02-25  $180,000.00
# 3  2487200875 2014-12-09  $604,000.00
# 4  1954400510 2015-02-18  $510,000.00

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  int64
#  1   date    21613 non-null  datetime64[ns]
#  2   price   21609 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 506.7+ KB

# %%
### DEFINE ###

#Change dtype of id to string
### CLEAN ### 

sales_df.id = sales_df.id.astype(str)
### TEST ###

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  object
#  1   date    21613 non-null  datetime64[ns]
#  2   price   21609 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 506.7+ KB

# %%
### DEFINE ###
#Remove$ sign, remove , in price column and then
#Change dtype of price to float
### CLEAN ### 
sales_df.price = sales_df.price.str.replace("$", "")
sales_df.price = sales_df.price.str.replace(",", "")
sales_df.price = sales_df.price.astype(float)
### TEST ###

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  object
#  1   date    21613 non-null  datetime64[ns]
#  2   price   21609 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 506.7+ KB
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_49031/4067150167.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sales_df.price = sales_df.price.str.replace("$", "")

# %%
sales_df.head()
# Out:
#            id       date     price
# 0  7129300520 2014-10-13  221900.0
# 1  6414100192 2014-12-09  538000.0
# 2  5631500400 2015-02-25  180000.0
# 3  2487200875 2014-12-09  604000.0
# 4  1954400510 2015-02-18  510000.0

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Done above

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.isna().sum()
# Out:
# id                   0
# bedrooms             0
# bathrooms            2
# sqft_living          0
# sqft_lot             2
# floors               0
# waterfront           8
# view                 2
# house_condition      6
# grade                2
# sqft_above           1
# sqft_basement        0
# year_built           1
# year_renovated     337
# zipcode              0
# lat                  1
# long                 1
# sqft_living_15       0
# sqft_lot_15          0
# dtype: int64

# %%
### DEFINE ### In house_df dataframe

#Delete year renovated column as there are too many missing values
### CLEAN ### 
house_df = house_df.drop(columns = ["year_renovated"])

### TEST ###

house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ### In house_df dataframe

#Use mean value to fill missing values in bathrooms, sqft_above, and sq_lot column.
### CLEAN ### 
mean = round(house_df.bathrooms.mean(), 1)
mean
house_df.bathrooms.fillna(mean, inplace =True)

### TEST ###

house_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           2
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              2
# sqft_above         1
# sqft_basement      0
# year_built         1
# zipcode            0
# lat                1
# long               1
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ### In house_df dataframe

#Use mean value to fill missing values in bathrooms, sqft_above, and sq_lot column.
### CLEAN ### 
mean = round(house_df.sqft_above.mean(), 1)
mean
house_df.sqft_above.fillna(mean, inplace =True)

### TEST ###

house_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           2
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              2
# sqft_above         0
# sqft_basement      0
# year_built         1
# zipcode            0
# lat                1
# long               1
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ### In house_df dataframe

#Use mean value to fill missing values in bathrooms, sqft_above, and sq_lot column.
### CLEAN ### 
mean = round(house_df.sqft_lot.mean(), 1)
mean
house_df.sqft_lot.fillna(mean, inplace =True)

### TEST ###

house_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              2
# sqft_above         0
# sqft_basement      0
# year_built         1
# zipcode            0
# lat                1
# long               1
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
house_df.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21613.000000  21611.000000  21613.000000  2.161100e+04  21613.000000
# mean       3.372091      2.115173   2079.899736  1.510388e+04      1.494309
# std        0.947533      0.772019    918.440897  4.141929e+04      0.539989
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      1.750000   1427.000000  5.040000e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.618000e+03      1.500000
# 75%        4.000000      2.500000   2550.000000  1.068750e+04      2.000000
# max       33.000000     10.000000  13540.000000  1.651359e+06      3.500000
#
#               grade    sqft_above  sqft_basement    year_built           lat  \
# count  21611.000000  21612.000000   21613.000000  21612.000000  21612.000000
# mean       7.656795   1788.861281     291.509045   1970.958079     47.560043
# ...

# %%
house_df[house_df.bathrooms.isna()]
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15]
# Index: []

# %%
### DEFINE ### In house_df dataframe

#Use mode to fill missing values in view column

### CLEAN ### 
mode_view = house_df.view.mode()[0]
house_df.view.fillna(mode_view, inplace=True)

### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21613 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21613 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21613 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21613 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  zipcode          21613 non-null  object
#  14  lat              21612 non-null  float64
#  15  long             21612 non-null  float64
# ...

# %%
### DEFINE ### In house_df dataframe

#Use mode to fill missing values in waterfront and grade columns

### CLEAN ### 
mode_waterfront = house_df.waterfront.mode()[0]
house_df.waterfront.fillna(mode_waterfront, inplace=True)

### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21613 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21613 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21613 non-null  object
#  7   view             21613 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21613 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  zipcode          21613 non-null  object
#  14  lat              21612 non-null  float64
#  15  long             21612 non-null  float64
# ...

# %%
### DEFINE ### In house_df dataframe

#Use mode to fill missing values in house condition column

### CLEAN ### 
mode_house_condition = house_df.house_condition.mode()[0]
house_df.house_condition.fillna(mode_house_condition, inplace=True)

### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21613 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21613 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21613 non-null  object
#  7   view             21613 non-null  object
#  8   house_condition  21613 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21613 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  zipcode          21613 non-null  object
#  14  lat              21612 non-null  float64
#  15  long             21612 non-null  float64
# ...

# %%
house_df.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21613.000000  21613.000000  21613.000000  2.161300e+04  21613.000000
# mean       3.372091      2.115171   2079.899736  1.510388e+04      1.494309
# std        0.947533      0.771983    918.440897  4.141737e+04      0.539989
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      1.750000   1427.000000  5.040000e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.620000e+03      1.500000
# 75%        4.000000      2.500000   2550.000000  1.068900e+04      2.000000
# max       33.000000     10.000000  13540.000000  1.651359e+06      3.500000
#
#               grade    sqft_above  sqft_basement    year_built           lat  \
# count  21611.000000  21613.000000   21613.000000  21612.000000  21612.000000
# mean       7.656795   1788.861283     291.509045   1970.958079     47.560043
# ...

# %%
### DEFINE ### In house_df dataframe

#Use mode to fill missing values in grade column

### CLEAN ### 
mode_grade = house_df.grade.mode()[0]
house_df.grade.fillna(mode_grade, inplace=True)

### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21613 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21613 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21613 non-null  object
#  7   view             21613 non-null  object
#  8   house_condition  21613 non-null  object
#  9   grade            21613 non-null  float64
#  10  sqft_above       21613 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  zipcode          21613 non-null  object
#  14  lat              21612 non-null  float64
#  15  long             21612 non-null  float64
# ...

# %%
### DEFINE ### In house_df dataframe

#Delete the rows with missing values in long,lat and year built columns
### CLEAN ### 

house_df.dropna(inplace = True)
### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21611 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21611 non-null  object
#  1   bedrooms         21611 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21611 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21611 non-null  float64
#  6   waterfront       21611 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21611 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21611 non-null  float64
#  11  sqft_basement    21611 non-null  int64
#  12  year_built       21611 non-null  float64
#  13  zipcode          21611 non-null  object
#  14  lat              21611 non-null  float64
#  15  long             21611 non-null  float64
# ...

# %%
### DEFINE ### Change view, waterfront and house_condition columns to categorical data

#
### CLEAN ### 

house_df.view = house_df.view.astype("category")
house_df.waterfront = house_df.waterfront.astype("category")
house_df.house_condition = house_df.house_condition.astype("category")
### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20452 entries, 0 to year_built
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20452 non-null  object
#  1   bedrooms         20452 non-null  int64
#  2   bathrooms        20452 non-null  float64
#  3   sqft_living      20452 non-null  int64
#  4   sqft_lot         20452 non-null  float64
#  5   floors           20452 non-null  float64
#  6   waterfront       20452 non-null  category
#  7   view             20452 non-null  category
#  8   house_condition  20452 non-null  category
#  9   grade            20452 non-null  float64
#  10  sqft_above       20452 non-null  float64
#  11  sqft_basement    20452 non-null  int64
#  12  year_built       20452 non-null  float64
#  13  zipcode          20452 non-null  object
#  14  lat              20452 non-null  float64
#  15  long             20452 non-null  float64
# ...

# %%
### DEFINE ### 

#Delete the rows with missing values in price from the sales_df dataframe
### CLEAN ### 
sales_df.dropna(inplace = True)

### TEST ###

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21609 non-null  object
#  1   date    21609 non-null  datetime64[ns]
#  2   price   21609 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 675.3+ KB

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.bedrooms.sort_values(ascending = False)
# Out:
# 15870    33
# 16       30
# 8757     11
# 19254    10
# 13314    10
#          ..
# 3119      0
# 12653     0
# 875       0
# 8484      0
# 3467      0
# Name: bedrooms, Length: 21611, dtype: int64

# %%
from scipy.stats import zscore

# %%
### DEFINE ###
#Delete outliers from bedrooms column
house_df.loc[house_df.bedrooms > 6]
### CLEAN ### 
house_df["bedrooms_zscore"] = zscore(house_df["bedrooms"])


#house_df.query("bedrooms_zscore >3 or bedrooms_zscore < -3")
index_out1 = house_df.loc[house_df.bedrooms_zscore <-3].index
index_out1
house_df.drop(index= [875, 3119, 3467, 4868, 6994, 8477, 8484, 9773, 9854, 12653, 14423,18379, 19452], inplace =True)
index_out2 = house_df.loc[house_df.bedrooms_zscore <-3].index
index_out2
##TEST##
house_df.loc[index_out1]
house_df.loc[index_out2]
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %%
### DEFINE ###
#Delete outliers from bathrooms column

### CLEAN ### 
house_df["bathrooms_zscore"] = zscore(house_df["bathrooms"])
house_df = house_df[house_df["bathrooms_zscore"] < 3] 
#
house_df = house_df[house_df["bathrooms_zscore"] > -3]

### TEST ###
house_df.query("bathrooms_zscore >3")
house_df.query("bathrooms_zscore < -3")
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %%
### DEFINE ###
#Delete outliers from sqft_living column

### CLEAN ### 
house_df.query("sqft_living_zscore >3 or sqft_living_zscore < -3")
house_df["sqft_living_zscore"] = zscore(house_df["sqft_living"])
house_df = house_df[house_df["sqft_living_zscore"] < 3] 
house_df = house_df[house_df["sqft_living_zscore"] > -3]

### TEST ###
house_df.query("sqft_living_zscore >3")
house_df.query("sqft_living_zscore < -3")
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %%
### DEFINE ###
#Delete outliers from sqft_lot column

### CLEAN ### 
house_df["sqft_lot_zscore"] = zscore(house_df["sqft_lot"])
house_df.query("sqft_lot_zscore >3 or sqft_lot_zscore < -3")

house_df = house_df[house_df["sqft_lot_zscore"] < 3] 
house_df = house_df[house_df["sqft_lot_zscore"] > -3]

### TEST ###
house_df.query("sqft_lot_zscore >3")
house_df.query("sqft_lot_zscore < -3")
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %%
### DEFINE ###
#Delete outliers from sqft_above column

### CLEAN ### 
house_df["sqft_above_zscore"] = zscore(house_df["sqft_above"])
house_df.query("sqft_above_zscore >3 or sqft_above_zscore < -3")
house_df = house_df[house_df["sqft_above_zscore"] < 3] 
house_df = house_df[house_df["sqft_above_zscore"] > -3]

### TEST ###
house_df.query("sqft_above_zscore >3")
house_df.query("sqft_above_zscore < -3")
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %%
### DEFINE ###
#Delete outliers from sqft_basement column

### CLEAN ### 
house_df["sqft_basement_zscore"] = zscore(house_df["sqft_basement"])
house_df.query("sqft_basement_zscore >3 or sqft_basement_zscore < -3")
house_df = house_df[house_df["sqft_basement_zscore"] < 3] 
house_df = house_df[house_df["sqft_basement_zscore"] > -3]

### TEST ###
house_df.query("sqft_basement_zscore >3")
house_df.query("sqft_basement_zscore < -3")
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %%
### DEFINE ###
#Delete outliers from year_built column

### CLEAN ### 

house_df["year_built_zscore"] = zscore(house_df["year_built"])
house_df.query("year_built_zscore >3 or year_built_zscore < -3")
house_df.drop(index= [20981], inplace =True)
house_df.drop(index= [21270], inplace =True)
### TEST ###
house_df.query("year_built_zscore >3 or year_built_zscore < -3")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_49031/558325066.py in <module>
#       6 house_df["year_built_zscore"] = zscore(house_df["year_built"])
#       7 house_df.query("year_built_zscore >3 or year_built_zscore < -3")
# ----> 8 house_df.drop(index= [20981], inplace =True)
#       9 #house_df.drop(index= [21270], inplace =True)
#      10 ### TEST ###
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
# ...

# %%
### DEFINE ###
#Delete outliers from sqft_living_15 column

### CLEAN ### 
house_df["sqft_living_15_zscore"] = zscore(house_df["sqft_living_15"])
house_df.query("sqft_living_15_zscore >3 or sqft_living_15_zscore < -3")
house_df = house_df[house_df["sqft_living_15_zscore"] < 3] 
house_df = house_df[house_df["sqft_basement_zscore"] > -3]

### TEST ###
house_df.query("sqft_living_15_zscore >3")
house_df.query("sqft_basement_zscore < -3")
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore, year_built_zscore, sqft_living_15_zscore]
# Index: []
#
# [0 rows x 26 columns]

# %%
### DEFINE ###
#Delete outliers from sqft_lot_15 column

### CLEAN ### 
house_df["sqft_lot_15_zscore"] = zscore(house_df["sqft_lot_15"])
house_df.query("sqft_lot_15_zscore >3 or sqft_lot_15_zscore < -3")
house_df.drop(index= [3801, 11183, 12669, 15557, 15620, 17659, 18524], inplace =True)
### TEST ###
house_df.query("year_built_zscore >3 or year_built_zscore < -3")
### TEST ###
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_basement_zscore, year_built_zscore, sqft_living_15_zscore, sqft_lot_15_zscore]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %% [markdown]
# ######################### TO DO ###################################
# Cleaning tasks completed and justification:
# Deleted Unanamed:0 column from house_df and sales_df dataframes because it was a duplicate
# Changed all column headers in house_df and sales_df to lower case for uniformity
# Changed all columns in house_df to snake case to get rid of spaces
# Removed ? from waterfront to get rid of special characters
# Changed dtype of zipcode to string in house_df as it is a descriptive variable and not used for calculations
# Changed dtype of id in both house_df and sales_df to string.
# Changed dtype of date column in sales_df to datetime as it is a date
# Removed the $ sign and comma from price column and changed dtype to float to get rid of special characters and make it quantitative data.
# Missing values:
# Deleted year_renovated column from house_df as it had over 300 missing values
# Filled missing values in bathrooms, sqft_above, and sqft_lot with mean values so data is not skewed
# Filled missing values in view, house condition, and waterfront, grade columns by mode as these fields are strings and descriptive data.
# Deleted the rows with missing values in long, lat and year built columns as there was just 1 missing  value in each of these columns
# Deleted rows with missing values in price column from the sales_df dataframe
# Treating Outliers:
# Deleted outliers that were not within +- 3 standard deviations from the mean  from all the columns that had outliers i.e, that had z scores >3 or < -3.
# The reason I deleted these was because the dataframe is large and deleting these would still give us  enough data to complete our analysis without skewing the data.
# Changed the datatype of view, house_condition and waterfront to categorical data as they have only few unique values.
# Dropped the additional columns created for zscores to get original dataframe cleaned.
#
# ####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.drop(columns= ["bedrooms_zscore", "bathrooms_zscore", "sqft_living_zscore", "sqft_lot_zscore", "sqft_above_zscore", "sqft_basement_zscore", "year_built_zscore", "sqft_living_15_zscore", "sqft_lot_15_zscore"], inplace =True)
house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  sqft_above  sqft_basement  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %% [markdown]
# ####### TO DO ###### - Edit this cell to add your summary and justification per project instructions.

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
#df_filtered = df[df['Age'] >= 25]
#indexwaterfront = house_df[ (house_df["waterfront"]= 2050).index
#house_df.drop(indexwaterfront , inplace=True)
#house_df = house_df[house_df["waterfront"] != 2050]
house_df.tail()
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 21607  2997800021         3       2.50         1310    1294.0     2.0
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 21607         No  Very Poor    OK Condition    8.0      1180.0            130
# 21608         No  Very Poor    OK Condition    8.0      1530.0              0
# 21609         No  Very Poor    OK Condition    8.0      2310.0              0
# 21611         No  Very Poor    OK Condition    8.0      1600.0              0
# 21612         No  Very Poor    OK Condition    7.0      1020.0              0
#
# ...

# %%
house_df.drop(columns= ["year_built_zscore"], inplace =True)
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20451 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20451 non-null  object
#  1   bedrooms         20451 non-null  int64
#  2   bathrooms        20451 non-null  float64
#  3   sqft_living      20451 non-null  int64
#  4   sqft_lot         20451 non-null  float64
#  5   floors           20451 non-null  float64
#  6   waterfront       20451 non-null  category
#  7   view             20451 non-null  category
#  8   house_condition  20451 non-null  category
#  9   grade            20451 non-null  float64
#  10  sqft_above       20451 non-null  float64
#  11  sqft_basement    20451 non-null  int64
#  12  year_built       20451 non-null  float64
#  13  zipcode          20451 non-null  object
#  14  lat              20451 non-null  float64
#  15  long             20451 non-null  float64
# ...

# %%
row = [2050]
house_df.loc[row]
# Out:
#               id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2050  8732040810         4       2.75         1770   10184.0     1.0
#
#      waterfront       view house_condition  grade  sqft_above  sqft_basement  \
# 2050         No  Very Poor    OK Condition    8.0      1250.0            520
#
#       year_built  zipcode      lat     long  sqft_living_15  sqft_lot_15
# 2050      1979.0  98023.0  47.3074 -122.385            2070         8320

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zj/15qg5mcs2svc83k3_z0qxg7h0000gn/T/ipykernel_49031/2285856503.py in <module>
# ----> 1 house_df.drop(house_df.loc[row], inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21609 non-null  object
#  1   date    21609 non-null  datetime64[ns]
#  2   price   21609 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 675.3+ KB

# %%
house_df[["waterfront", "view", "house_condition"]].describe()
# Out:
#        waterfront       view house_condition
# count       20451      20451           20451
# unique          2          5               5
# top            No  Very Poor    OK Condition
# freq        20331      18719           13200

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# - view
# - waterfront
# - house_condition
# - ########## TO DO ########### ........

# %%
house_df.view.unique()
# Out:
# ['Very Poor', 'Good', 'Neutral', 'Great', 'Poor']
# Categories (6, object): [2050, 'Good', 'Great', 'Neutral', 'Poor', 'Very Poor']

# %%
house_df.waterfront.unique()
# Out:
# ['No', 'Yes']
# Categories (3, object): [2050, 'No', 'Yes']

# %%
house_df.house_condition.unique()
# Out:
# ['OK Condition', 'Great Condition', 'Good Condition', 'Very Bad Condition', 'Bad Condition']
# Categories (6, object): [2050, 'Bad Condition', 'Good Condition', 'Great Condition', 'OK Condition', 'Very Bad Condition']

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %% [markdown]
# ######################### TO DO ###################################
# Change view from very poor, good, neutral, great, poor to a scale of 1- 5 with 1 being very poor and 5 being great as having a scale makes the dataframe easier to read and manipulate
# Change hosue_conditon from Ok/Bad etc to a scale of 1-5 where 1 = very poor as the scale is easier to read in dataframe
# Change waterfront from Yes/No to 1/0 as it is a boolean
# ####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to re-express each variable and why.

# %% [markdown]
# ### Step 3: Perform Transformation

# %%
######################### TO DO ###################################
house_df["view"] = house_df["view"].replace({"Very Poor": 1, "Poor": 2, "Neutral": 3, "Good": 4, "Great": 5})
house_df.view.unique()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# [1, 4, 3, 5, 2]
# Categories (6, int64): [2050, 4, 5, 3, 2, 1]

# %%
######################### TO DO ###################################
house_df["house_condition"] = house_df["house_condition"].replace({"Very Bad Condition": 1, "Bad Condition": 2, "OK Condition": 3, "Good Condition": 4, "Great Condition": 5})
house_df.house_condition.unique()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# [3, 5, 4, 1, 2]
# Categories (6, int64): [2050, 2, 4, 5, 3, 1]

# %%
######################### TO DO ###################################
house_df["waterfront"] = house_df["waterfront"].replace({"Yes": 1, "No": 0})
house_df.waterfront.unique()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# [0, 1]
# Categories (3, int64): [2050, 0, 1]

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %% [markdown]
# ######################### TO DO ###################################
# Changed view to scale from 1-5
# Changed house condition to scalre from 1-5
# Changed waterfront to boolean 0 for No and 1 for yes
# ####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to add your summary and justification per project instructions.

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %% [markdown]
# ######################### TO DO ###################################
# I am using the merge method as stated in the project directions
# ####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to merge the data and why.

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################
master_df = sales_df.merge(house_df, on='id')

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
# Use .head() method to print first few rows of new master dataframe
master_df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront view house_condition  grade  sqft_above  \
# 0    5650.0     1.0          0    1               3    7.0      1180.0
# 1    7242.0     2.0          0    1               3    7.0      2170.0
# 2   10000.0     1.0          0    1               3    6.0       770.0
# 3    5000.0     1.0          0    1               5    7.0      1050.0
# 4    8080.0     1.0          0    1               3    8.0      1680.0
#
#    sqft_basement  year_built  zipcode      lat     long  sqft_living_15  \
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20794 entries, 0 to 20793
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20794 non-null  object
#  1   date             20794 non-null  datetime64[ns]
#  2   price            20794 non-null  float64
#  3   bedrooms         20794 non-null  int64
#  4   bathrooms        20794 non-null  float64
#  5   sqft_living      20794 non-null  int64
#  6   sqft_lot         20794 non-null  float64
#  7   floors           20794 non-null  float64
#  8   waterfront       20794 non-null  category
#  9   view             20794 non-null  category
#  10  house_condition  20794 non-null  category
#  11  grade            20794 non-null  float64
#  12  sqft_above       20794 non-null  float64
#  13  sqft_basement    20794 non-null  int64
#  14  year_built       20794 non-null  float64
#  15  zipcode          20794 non-null  object
# ...

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################
master_df.to_csv('master.csv', index=False)
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
